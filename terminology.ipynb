# %% [markdown]
# # Explore Buddhist Terminology

# %%
# !pip install pandas matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Use the "raw" URL instead of the "blob" URL
raw_url = 'https://raw.githubusercontent.com/Silk-Road-Corpus/silk_road_corpus/main/data/terminology_analysis.csv'

try:
    df = pd.read_csv(raw_url, index_col=0)
    print("Successfully loaded the data!")
    print(df.shape)
    print(df.head())
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# Look up a term

# %%
df.loc["十現色入"]
